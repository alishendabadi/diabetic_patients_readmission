# %%
# !pip install -r requirements.txt

# %%
# !python3 diabetic_readmission_classification.py
# Out:
# DIABETIC PATIENT READMISSION CLASSIFICATION
# ...
# Loading data...
# Dataset shape: (101766, 48)
# Columns: 48
#
# === DATASET OVERVIEW ===
# Total samples: 101766
# Total features: 48
#
# === TARGET VARIABLE DISTRIBUTION ===
# readmitted
# NO     54864
# >30    35545
# <30    11357
# Name: count, dtype: int64
#
# Target variable distribution (%):
# readmitted
# NO     53.911916
# >30    34.928169
# <30    11.159916
# Name: proportion, dtype: float64
#
# === MISSING VALUES ===
#                    Missing Count  Missing Percent
# weight                     98569        96.858479
# medical_specialty          49949        49.082208
# payer_code                 40256        39.557416
# race                        2273         2.233555
# diag_3                      1423         1.398306
# diag_2                       358         0.351787
# diag_1                        21         0.020636
#
# === PREPROCESSING DATA ===
# Handling missing values...
# ...

# %%
# !python3 model_explainability.py
# Out:
# MODEL EXPLAINABILITY ANALYSIS
# ...
# Loading best model...
# Available Models:
# LogisticRegression_undersample_model.pkl
# XGBoost_undersample_model.pkl
# LightGBM_undersample_model.pkl
# MLP_undersample_model.pkl
# SVM_undersample_model.pkl
# RandomForest_undersample_model.pkl
# Enter the name of model file you want to run XAI script on: LightGBM_undersample_model.pkl
# Model: LightGBM
# Balance method: undersample
# Recall for <30 days: 0.3562
# Loading test data...
# Handling missing values...
# Dropping columns with >35% missing values: ['weight', 'payer_code', 'medical_specialty']
#
# === SHAP Analysis for LightGBM ===
# Using TreeExplainer for tree-based model...
# Calculating SHAP values...
# Figure(800x950)
#
# === EXPLAINABILITY ANALYSIS COMPLETE ===
